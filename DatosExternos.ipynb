# %% [markdown]
# ### Hacerse cuenta aqui:

# %%
import pandas as pd

ciudad = "Madrid"
fecha_inicio = "2021-01-01"
fecha_fin = "2022-01-01"
api_key = "552UVBDLNR84REZGTPJDLLH9A"

url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{ciudad}/{fecha_inicio}/{fecha_fin}?unitGroup=metric&include=days&key={api_key}&contentType=csv"

df_clima1 = pd.read_csv(url)
df_clima1.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[40], line 10
#       6 api_key = "552UVBDLNR84REZGTPJDLLH9A"
#       8 url = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{ciudad}/{fecha_inicio}/{fecha_fin}?unitGroup=metric&include=days&key={api_key}&contentType=csv"
# ---> 10 df_clima1 = pd.read_csv(url)
#      11 df_clima1.head()
#
# ...

# %%
ciudad = "Madrid"
fecha_inicio = "2022-01-01"
fecha_fin = "2023-01-01"
api_key = "552UVBDLNR84REZGTPJDLLH9A"

url2 = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{ciudad}/{fecha_inicio}/{fecha_fin}?unitGroup=metric&include=days&key={api_key}&contentType=csv"

df_clima2 = pd.read_csv(url2)
df_clima2.head()

# %%
ciudad = "Madrid"
fecha_inicio = "2023-01-01"
fecha_fin = "2024-01-01"
api_key = "552UVBDLNR84REZGTPJDLLH9A"

url3 = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{ciudad}/{fecha_inicio}/{fecha_fin}?unitGroup=metric&include=days&key={api_key}&contentType=csv"

df_clima3 = pd.read_csv(url3)
df_clima3.head()

# %%
ciudad = "Madrid"
fecha_inicio = "2024-01-01"
fecha_fin = "2024-09-10"
api_key = "552UVBDLNR84REZGTPJDLLH9A"

url4 = f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{ciudad}/{fecha_inicio}/{fecha_fin}?unitGroup=metric&include=days&key={api_key}&contentType=csv"

df_clima4 = pd.read_csv(url4)
df_clima4.head()

# %%
df_clima1 = df_clima1[['datetime','temp','windgust','windspeed','conditions']]
df_clima1
# Out:
#        datetime  temp  windgust  windspeed              conditions
# 0    2023-06-01  17.2      27.4       15.9  Rain, Partially cloudy
# 1    2023-06-02  17.3      20.9       13.6  Rain, Partially cloudy
# 2    2023-06-03  18.0      19.1       23.0  Rain, Partially cloudy
# 3    2023-06-04  19.4      22.0       10.0  Rain, Partially cloudy
# 4    2023-06-05  19.8      25.9       18.2  Rain, Partially cloudy
# ..          ...   ...       ...        ...                     ...
# 371  2024-06-06  26.5      29.2       15.2  Rain, Partially cloudy
# 372  2024-06-07  26.7      41.4       28.3  Rain, Partially cloudy
# 373  2024-06-08  19.5      35.3       23.1  Rain, Partially cloudy
# 374  2024-06-09  18.9      24.5       15.1  Rain, Partially cloudy
# 375  2024-06-10  16.6      28.4       10.7  Rain, Partially cloudy
#
# [376 rows x 5 columns]

# %%
df_clima2 = df_clima2[['datetime','temp','windgust','windspeed','conditions']]
df_clima2

# %%
df_clima3 = df_clima3[['datetime','temp','windgust','windspeed','conditions']]
df_clima3

# %%
df_clima4 = df_clima4[['datetime','temp','windgust','windspeed','conditions']]
df_clima4
